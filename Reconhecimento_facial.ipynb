# %% [markdown]
# <a href="https://colab.research.google.com/github/hiltonjr-tech/Binary_images/blob/main/Reconhecimento_facial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 31.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.2 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=d89cf3ad728f5d59d37f2c9b7f5f90bb6eeb6ef4b3bd2989dfecd7777789d955
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
from deepface import DeepFace
# Out:
# 25-01-29 20:01:25 - Directory /root/.deepface has been created
# 25-01-29 20:01:25 - Directory /root/.deepface/weights has been created

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt

# %%
img1_path='/content/img1.jpeg'

# %%
img2_path='/content/img2.jpeg'

# %%
img3_path='/content/img3.jpeg'

# %%
img1_to_display = img1[0]

# %%
plt.imshow(img1_to_display)

# %%
img2_to_display = img2[0]
plt.imshow(img2_to_display)

# %%
img3_to_display = img3[0]
plt.imshow(img3_to_display)

# %%
model_name='Facenet'

# %%
result = DeepFace.verify(img1_path=img1_path,img2_path=img2_path,model_name=model_name)
# Out:
# 25-01-29 21:00:47 - facenet_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facenet_weights.h5
# To: /root/.deepface/weights/facenet_weights.h5
# 100%|██████████| 92.2M/92.2M [00:00<00:00, 104MB/s]

# %%
result
# Out:
# {'verified': False,
#  'distance': 0.5419293303853743,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 229,
#    'y': 114,
#    'w': 144,
#    'h': 144,
#    'left_eye': None,
#    'right_eye': None},
#   'img2': {'x': 119,
#    'y': 90,
#    'w': 170,
#    'h': 170,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 8.85}
